# %% [markdown]
# # Basic Analysis

# %%
import pandas as pd

# %%
oo = pd.read_csv('../data/olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26392/2075066311.py in <module>
# ----> 1 pd.read_excel('C:\\Users\\jdyeh\\OneDrive - Microsoft\\Documents\\CSU Scrum\\Pull of Milestones.xlsx')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %% [markdown]
# ### value_counts()

# %%
oo.NOC.value_counts()
# Out:
# USA    4335
# URS    2049
# GBR    1594
# FRA    1314
# ITA    1228
#        ...
# TGA       1
# DJI       1
# AHO       1
# BDI       1
# AFG       1
# Name: NOC, Length: 138, dtype: int64

# %%
oo.Gender.value_counts(ascending=True,dropna=False)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# ### sort_values()

# %%
ath = oo.Athlete.sort_values()
ath
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
oo.sort_values(by=['Edition','Athlete'])
# Out:
#           City  Edition          Sport       Discipline  \
# 7       Athens     1896       Aquatics         Swimming
# 82      Athens     1896     Gymnastics      Artistic G.
# 110     Athens     1896     Gymnastics      Artistic G.
# 111     Athens     1896     Gymnastics      Artistic G.
# 48      Athens     1896        Cycling     Cycling Road
# 19      Athens     1896      Athletics        Athletics
# 134     Athens     1896         Tennis           Tennis
# 140     Athens     1896         Tennis           Tennis
# 13      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 84      Athens     1896     Gymnastics      Artistic G.
# 99      Athens     1896     Gymnastics      Artistic G.
# 66      Athens     1896        Fencing          Fencing
# 4       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# ...

# %%
oo.sort_values(by=['Edition','Medal','NOC'])
# Out:
#           City  Edition          Sport       Discipline           Athlete  \
# 53      Athens     1896        Cycling    Cycling Track     SCHMAL, Adolf
# 58      Athens     1896        Cycling    Cycling Track     SCHMAL, Adolf
# 69      Athens     1896        Fencing          Fencing   NIELSEN, Holger
# 120     Athens     1896       Shooting         Shooting   NIELSEN, Holger
# 129     Athens     1896       Shooting         Shooting     JENSEN, Viggo
# ...        ...      ...            ...              ...               ...
# 29176  Beijing     2008      Wrestling  Wrestling Free.    TIGIEV, Soslan
# 29102  Beijing     2008  Weightlifting    Weightlifting   HOANG, Anh Tuan
# 27216  Beijing     2008       Aquatics         Swimming  COVENTRY, Kirsty
# 27268  Beijing     2008       Aquatics         Swimming  COVENTRY, Kirsty
# 27280  Beijing     2008       Aquatics         Swimming  COVENTRY, Kirsty
#
#        NOC Gender                             Event Event_gender   Medal
# ...

# %% [markdown]
# ### Boolean indexing

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
notgold = oo[~(oo.Medal == 'Gold')]
notgold
# Out:
#           City  Edition      Sport       Discipline                Athlete  \
# 1       Athens     1896   Aquatics         Swimming       HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming      DRIVAS, Dimitrios
# 4       Athens     1896   Aquatics         Swimming     CHASAPIS, Spiridon
# 5       Athens     1896   Aquatics         Swimming  CHOROPHAS, Efstathios
# 7       Athens     1896   Aquatics         Swimming       ANDREOU, Joannis
# ...        ...      ...        ...              ...                    ...
# 29209  Beijing     2008  Wrestling  Wrestling Gre-R          WHEELER, Adam
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R         ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R   MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R        PATRIKEEV, Yuri
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R         BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
notgold.to_csv('C:\\Users\\jdyeh\\OneDrive - Microsoft\\Desktop\\Ex_Files_Python_Excel\\basic_info.csv')

# %%
ls files
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 9EF5-3A92
#
#  Directory of C:\Users\jdyeh\OneDrive - Microsoft\Desktop\Ex_Files_Python_Excel\Ex_Files_Pandas_EssT\Ch04
# File Not Found

# %% [markdown]
# ### String handling

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %%
oo = pd.read_csv('../data/olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo[(oo.Discipline == "Swimming") & (oo.Medal == 'Gold')]
# Out:
#           City  Edition     Sport Discipline                   Athlete  NOC  \
# 0       Athens     1896  Aquatics   Swimming             HAJOS, Alfred  HUN
# 3       Athens     1896  Aquatics   Swimming        MALOKINIS, Ioannis  GRE
# 6       Athens     1896  Aquatics   Swimming             HAJOS, Alfred  HUN
# 9       Athens     1896  Aquatics   Swimming             NEUMANN, Paul  AUT
# 152      Paris     1900  Aquatics   Swimming       JARVIS, John Arthur  GBR
# ...        ...      ...       ...        ...                       ...  ...
# 27396  Beijing     2008  Aquatics   Swimming        CIELO FILHO, Cesar  BRA
# 27399  Beijing     2008  Aquatics   Swimming           STEFFEN, Britta  GER
# 27402  Beijing     2008  Aquatics   Swimming        ADLINGTON, Rebecca  GBR
# 27405  Beijing     2008  Aquatics   Swimming  VAN DER WEIJDEN, Maarten  NED
# 27408  Beijing     2008  Aquatics   Swimming          ILCHENKO, Larisa  RUS
#
# ...

# %%
oo[oo.Athlete.str.contains('OWENS, Jesse')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
filter2 = oo[(oo.Discipline.str.contains('Badminton')) & (oo.Medal == 'Gold') & (oo.Gender == 'Men') & (oo.Event == 'singles')]

# %%
filter2.sort_values(by=['Athlete'])
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 25734    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 23717    Men  singles            M  Gold
# 27741    Men  singles            M  Gold

# %%
filter4 = oo[(oo.Medal == 'Gold') & (oo.Gender == 'Men') & (oo.Event == '100m') & (oo.Edition >= 1960)]
filter4.sort_values(by=['Edition'], ascending=False)
# Out:
#               City  Edition      Sport Discipline            Athlete  NOC  \
# 27552      Beijing     2008  Athletics  Athletics        BOLT, Usain  JAM
# 25539       Athens     2004  Athletics  Athletics     GATLIN, Justin  USA
# 23521       Sydney     2000  Athletics  Athletics    GREENE, Maurice  USA
# 21598      Atlanta     1996  Athletics  Athletics    BAILEY, Donovan  CAN
# 19859    Barcelona     1992  Athletics  Athletics  CHRISTIE, Linford  GBR
# 18284        Seoul     1988  Athletics  Athletics        LEWIS, Carl  USA
# 16794  Los Angeles     1984  Athletics  Athletics        LEWIS, Carl  USA
# 15374       Moscow     1980  Athletics  Athletics       WELLS, Allan  GBR
# 14069     Montreal     1976  Athletics  Athletics   CRAWFORD, Hasely  TRI
# 12902       Munich     1972  Athletics  Athletics     BORZOV, Valery  URS
# 11865       Mexico     1968  Athletics  Athletics   HINES, James Ray  USA
# 10823        Tokyo     1964  Athletics  Athletics      HAYES, Robert  USA
# ...

# %%
filter3 = oo[(oo.Edition >= 1984) ]
filter3.NOC.value_counts().head(3)
# oo.NOC.value_counts()
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64
